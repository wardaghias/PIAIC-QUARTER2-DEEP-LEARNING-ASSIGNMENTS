# %% [markdown]
# # Credit Card Fraud Detection

# %% [markdown]
# Download dataset from this link:
#
# https://www.kaggle.com/mlg-ulb/creditcardfraud

# %% [markdown]
# # Description about dataset::

# %% [markdown]
# The datasets contains transactions made by credit cards in September 2013 by european cardholders.
# This dataset presents transactions that occurred in two days, where we have 492 frauds out of 284,807 transactions. The dataset is highly unbalanced, the positive class (frauds) account for 0.172% of all transactions.
#
# It contains only numerical input variables which are the result of a PCA transformation. Unfortunately, due to confidentiality issues, we cannot provide the original features and more background information about the data. Features V1, V2, … V28 are the principal components obtained with PCA, the only features which have not been transformed with PCA are 'Time' and 'Amount'. Feature 'Time' contains the seconds elapsed between each transaction and the first transaction in the dataset. The feature 'Amount' is the transaction Amount, this feature can be used for example-dependant cost-senstive learning.
#
#
# ### Feature 'Class' is the response variable and it takes value 1 in case of fraud and 0 otherwise.

# %% [markdown]
# # WORKFLOW :

# %% [markdown]
# 1.Load Data
#
# 2.Check Missing Values ( If Exist ; Fill each record with mean of its feature )
#
# 3.Standardized the Input Variables.
#
# 4.Split into 50% Training(Samples,Labels) , 30% Test(Samples,Labels) and 20% Validation Data(Samples,Labels).
#
# 5.Model : input Layer (No. of features ), 3 hidden layers including 10,8,6 unit & Output Layer with activation function relu/tanh (check by experiment).
#
# 6.Compilation Step (Note : Its a Binary problem , select loss , metrics according to it)
#
# 7.Train the Model with Epochs (100).
#
# 8.If the model gets overfit tune your model by changing the units , No. of layers , epochs , add dropout layer or add Regularizer according to the need .
#
# 9.Prediction should be > 92%
# 10.Evaluation Step
# 11Prediction

# %% [markdown]
# # Task::

# %% [markdown]
# ## Identify fraudulent credit card transactions.

# %% [markdown]
# ## Load Data

# %%
import pandas as pd 
import numpy as np 
import tensorflow as tf 
from tensorflow.keras import models, layers, optimizers

# %%
data = pd.read_csv('creditcard.csv')
data
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %% [markdown]
# ## 2.Check Missing Values ( If Exist ; Fill each record with mean of its feature )

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
np.where(data.applymap(lambda x : x == '' or x == ' '))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %% [markdown]
# ## 3.Standardized the Input Variables

# %%
data.shape
# Out:
# (284807, 31)

# %%
targets = data['Class']
targets
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 284807, dtype: int64

# %%
data1 = data.drop(columns=['Class'])
data1
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V20       V21  \
# 0       0.462388  0.239599  0.098698  0.363787  ...  0.251412 -0.018307
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.069083 -0.225775
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.524980  0.247998
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.208038 -0.108300
# 4       0.095921  0.592941 -0.270533  0.817739  ...  0.408542 -0.009431
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  1.475829  0.213454
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.059616  0.214205
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.001396  0.232045
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.127434  0.265245
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.382948  0.261057
#
#              V22       V23       V24       V25       V26       V27       V28  \
# 0       0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053
# 1      -0.638672  0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724
# 2       0.771679  0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752
# 3       0.005274 -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458
# 4       0.798278 -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802  0.111864  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731
# 284803  0.924384  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527
# 284804  0.578229 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561
# 284805  0.800049 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533
# 284806  0.643078  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649
#
#         Amount
# 0       149.62
# 1         2.69
# 2       378.66
# 3       123.50
# 4        69.99
# ...        ...
# 284802    0.77
# 284803   24.79
# 284804   67.88
# 284805   10.00
# 284806  217.00
#
# [284807 rows x 30 columns]

# %%
data.dtypes
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
data.Amount.value_counts()[0]
# Out:
# 1825

# %% [markdown]
# ## 4.Split into 50% Training(Samples,Labels) , 30% Test(Samples,Labels) and 20% Validation Data(Samples,Labels).

# %%
np.random.seed(225)
mask1 = np.random.rand(len(data1)) < 0.50
train_data = data1[mask1]
test_data = data1[~mask1]

# %%
train_data.shape, test_data.shape
# Out:
# ((142621, 30), (142186, 30))

# %%
train_targets = targets[mask1]
test_targets = targets[~mask1]

# %%
len(data)*0.2
# Out:
# 56961.4

# %%
val_data = train_data[:round(len(data)*0.2)]
val_targets = train_targets[:round(len(data)*0.2)]
train_data = train_data[round(len(data)*0.2):]
train_targets = train_targets[round(len(data)*0.2):]

# %%
len(val_data), len(val_targets)
# Out:
# (56961, 56961)

# %% [markdown]
#  ## 5.Model : input Layer (No. of features ), 3 hidden layers including 10,8,6 unit & Output Layer with activation function relu/tanh (check by experiment).
#  ## 6.Compilation Step (Note : Its a Binary problem , select loss , metrics according to it)

# %%
network = models.Sequential()
network.add(layers.Dense(10, activation='relu', input_shape=(train_data.shape[1],)))
network.add(layers.Dense(8, activation='relu'))
network.add(layers.Dense(6, activation='relu'))
network.add(layers.Dense(1, activation='sigmoid'))
network.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## 7.Train the Model with Epochs (100).

# %%
network.fit(train_data, train_targets, epochs=100, batch_size=128, validation_data=(val_data, val_targets) )
# Out:
# Epoch 1/100
# 670/670 [==============================] - 4s 5ms/step - loss: 3.2794 - accuracy: 0.9737 - val_loss: 0.4672 - val_accuracy: 0.9979
# Epoch 2/100
# 670/670 [==============================] - 2s 3ms/step - loss: 0.4099 - accuracy: 0.9986 - val_loss: 0.2818 - val_accuracy: 0.9979
# Epoch 3/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.2520 - accuracy: 0.9985 - val_loss: 0.1865 - val_accuracy: 0.9979
# Epoch 4/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.1669 - accuracy: 0.9987 - val_loss: 0.1304 - val_accuracy: 0.9979
# Epoch 5/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.1165 - accuracy: 0.9985 - val_loss: 0.0950 - val_accuracy: 0.9979
# Epoch 6/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0833 - accuracy: 0.9988 - val_loss: 0.0716 - val_accuracy: 0.9979
# Epoch 7/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0621 - accuracy: 0.9985 - val_loss: 0.0556 - val_accuracy: 0.9979
# Epoch 8/100
# 670/670 [==============================] - 2s 3ms/step - loss: 0.0470 - accuracy: 0.9986 - val_loss: 0.0445 - val_accuracy: 0.9979
# Epoch 9/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0361 - accuracy: 0.9987 - val_loss: 0.0367 - val_accuracy: 0.9979
# Epoch 10/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0284 - accuracy: 0.9987 - val_loss: 0.0311 - val_accuracy: 0.9979
# Epoch 11/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0235 - accuracy: 0.9986 - val_loss: 0.0271 - val_accuracy: 0.9979
# Epoch 12/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0192 - accuracy: 0.9987 - val_loss: 0.0243 - val_accuracy: 0.9979
# Epoch 13/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0169 - accuracy: 0.9986 - val_loss: 0.0224 - val_accuracy: 0.9979
# Epoch 14/100
# 670/670 [==============================] - 2s 2ms/step - loss: 0.0157 - accuracy: 0.9984 - val_loss: 0.0210 - val_accuracy: 0.9979
# Epoch 15/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0129 - accuracy: 0.9987 - val_loss: 0.0201 - val_accuracy: 0.9979
# Epoch 16/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0130 - accuracy: 0.9985 - val_loss: 0.0196 - val_accuracy: 0.9979
# Epoch 17/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0126 - accuracy: 0.9984 - val_loss: 0.0193 - val_accuracy: 0.9979
# Epoch 18/100
# 670/670 [==============================] - 2s 3ms/step - loss: 0.0130 - accuracy: 0.9983 - val_loss: 0.0191 - val_accuracy: 0.9979
# Epoch 19/100
# 670/670 [==============================] - 2s 2ms/step - loss: 0.0117 - accuracy: 0.9985 - val_loss: 0.0190 - val_accuracy: 0.9979
# Epoch 20/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0109 - accuracy: 0.9986 - val_loss: 0.0190 - val_accuracy: 0.9979
# Epoch 21/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0114 - accuracy: 0.9985 - val_loss: 0.0190 - val_accuracy: 0.9979
# Epoch 22/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0101 - accuracy: 0.9987 - val_loss: 0.0191 - val_accuracy: 0.9979
# Epoch 23/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0113 - accuracy: 0.9985 - val_loss: 0.0191 - val_accuracy: 0.9979
# Epoch 24/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0125 - accuracy: 0.9983 - val_loss: 0.0191 - val_accuracy: 0.9979
# Epoch 25/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0104 - accuracy: 0.9986 - val_loss: 0.0191 - val_accuracy: 0.9979
# Epoch 26/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0134 - accuracy: 0.9982 - val_loss: 0.0191 - val_accuracy: 0.9979
# Epoch 27/100
# 670/670 [==============================] - 2s 3ms/step - loss: 0.0107 - accuracy: 0.9986 - val_loss: 0.0191 - val_accuracy: 0.9979
# Epoch 28/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0110 - accuracy: 0.9985 - val_loss: 0.0191 - val_accuracy: 0.9979
# Epoch 29/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0115 - accuracy: 0.9985 - val_loss: 0.0191 - val_accuracy: 0.9979
# Epoch 30/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0110 - accuracy: 0.9985 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 31/100
# 670/670 [==============================] - 2s 2ms/step - loss: 0.0109 - accuracy: 0.9986 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 32/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0113 - accuracy: 0.9985 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 33/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0115 - accuracy: 0.9985 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 34/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0098 - accuracy: 0.9987 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 35/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0119 - accuracy: 0.9984 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 36/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0116 - accuracy: 0.9984 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 37/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0110 - accuracy: 0.9985 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 38/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0109 - accuracy: 0.9986 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 39/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0113 - accuracy: 0.9985 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 40/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0106 - accuracy: 0.9986 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 41/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0106 - accuracy: 0.9986 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 42/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0112 - accuracy: 0.9985 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 43/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0120 - accuracy: 0.9984 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 44/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0105 - accuracy: 0.9986 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 45/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0095 - accuracy: 0.9988 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 46/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0122 - accuracy: 0.9984 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 47/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0094 - accuracy: 0.9988 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 48/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0115 - accuracy: 0.9985 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 49/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0119 - accuracy: 0.9984 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 50/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0103 - accuracy: 0.9986 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 51/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0108 - accuracy: 0.9986 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 52/100
# 670/670 [==============================] - 2s 3ms/step - loss: 0.0111 - accuracy: 0.9985 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 53/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0106 - accuracy: 0.9986 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 54/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0117 - accuracy: 0.9984 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 55/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0118 - accuracy: 0.9984 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 56/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0096 - accuracy: 0.9988 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 57/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0109 - accuracy: 0.9986 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 58/100
# 670/670 [==============================] - 2s 2ms/step - loss: 0.0108 - accuracy: 0.9986 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 59/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0113 - accuracy: 0.9985 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 60/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0102 - accuracy: 0.9987 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 61/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0114 - accuracy: 0.9985 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 62/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0112 - accuracy: 0.9985 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 63/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0107 - accuracy: 0.9986 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 64/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0120 - accuracy: 0.9984 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 65/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0122 - accuracy: 0.9984 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 66/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0112 - accuracy: 0.9985 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 67/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0114 - accuracy: 0.9985 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 68/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0108 - accuracy: 0.9986 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 69/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0095 - accuracy: 0.9988 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 70/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0108 - accuracy: 0.9986 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 71/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0109 - accuracy: 0.9986 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 72/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0109 - accuracy: 0.9985 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 73/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0119 - accuracy: 0.9984 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 74/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0125 - accuracy: 0.9983 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 75/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0118 - accuracy: 0.9984 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 76/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0116 - accuracy: 0.9984 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 77/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0123 - accuracy: 0.9983 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 78/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0114 - accuracy: 0.9985 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 79/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0115 - accuracy: 0.9985 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 80/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0107 - accuracy: 0.9986 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 81/100
# 670/670 [==============================] - 2s 3ms/step - loss: 0.0107 - accuracy: 0.9986 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 82/100
# 670/670 [==============================] - 2s 3ms/step - loss: 0.0122 - accuracy: 0.9984 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 83/100
# 670/670 [==============================] - 2s 3ms/step - loss: 0.0101 - accuracy: 0.9987 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 84/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0116 - accuracy: 0.9984 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 85/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0110 - accuracy: 0.9985 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 86/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0128 - accuracy: 0.9983 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 87/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0113 - accuracy: 0.9985 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 88/100
# 670/670 [==============================] - 2s 3ms/step - loss: 0.0116 - accuracy: 0.9984 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 89/100
# 670/670 [==============================] - 2s 3ms/step - loss: 0.0114 - accuracy: 0.9985 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 90/100
# 670/670 [==============================] - 2s 2ms/step - loss: 0.0099 - accuracy: 0.9987 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 91/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0101 - accuracy: 0.9987 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 92/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0114 - accuracy: 0.9985 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 93/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0113 - accuracy: 0.9985 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 94/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0123 - accuracy: 0.9983 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 95/100
# 670/670 [==============================] - 2s 2ms/step - loss: 0.0124 - accuracy: 0.9983 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 96/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0097 - accuracy: 0.9987 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 97/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0129 - accuracy: 0.9982 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 98/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0123 - accuracy: 0.9983 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 99/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0118 - accuracy: 0.9984 - val_loss: 0.0192 - val_accuracy: 0.9979
# Epoch 100/100
# 670/670 [==============================] - 1s 2ms/step - loss: 0.0106 - accuracy: 0.9986 - val_loss: 0.0192 - val_accuracy: 0.9979

# %%
network.evaluate(test_data, test_targets)
# Out:
# 4444/4444 [==============================] - 4s 983us/step - loss: 0.0135 - accuracy: 0.9983
# [0.01345297321677208, 0.9982909560203552]
